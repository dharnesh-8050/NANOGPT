# %% [markdown]
# <a href="https://colab.research.google.com/github/dharnesh-8050/NANOGPT/blob/main/NanoGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 Words = open ('names.txt', 'r').read().splitlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_25143/401805254.py in <cell line: 0>()
# ----> 1 Words = open ('names.txt', 'r').read().splitlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'names.txt'

# %%
words[:10]
